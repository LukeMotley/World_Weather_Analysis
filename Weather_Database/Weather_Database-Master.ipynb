# %%
# Import Dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import import_ipynb

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Basic URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cf67206b482d3c03b62858bc4df0062'

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city in unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficiient count.
len(cities)
# Out:
# 757

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | antofagasta
# Processing Record 5 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | san cristobal
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 1 | staraya poltavka
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | atambua
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | kaitangata
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | chumphon
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | montepuez
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | chavakkad
# Processing Record 24 of Set 1 | zeya
# Processing Record 25 of Set 1 | boden
# Processing Record 26 of Set 1 | salalah
# Processing Record 27 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 1 | okha
# Processing Record 29 of Set 1 | saint anthony
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | hirara
# Processing Record 32 of Set 1 | tigil
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | the valley
# Processing Record 37 of Set 1 | hay river
# Processing Record 38 of Set 1 | vardo
# Processing Record 39 of Set 1 | wittenheim
# Processing Record 40 of Set 1 | tuktoyaktuk
# Processing Record 41 of Set 1 | pangai
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | abha
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | kodinar
# Processing Record 48 of Set 1 | lanzhou
# Processing Record 49 of Set 1 | dunedin
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | harrison
# Processing Record 4 of Set 2 | ambilobe
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 2 | bundaberg
# Processing Record 8 of Set 2 | dodge city
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | kalabo
# Processing Record 11 of Set 2 | christchurch
# Processing Record 12 of Set 2 | manggar
# Processing Record 13 of Set 2 | sassandra
# Processing Record 14 of Set 2 | kamina
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | fairbanks
# Processing Record 17 of Set 2 | vrede
# Processing Record 18 of Set 2 | ponta do sol
# Processing Record 19 of Set 2 | namibe
# Processing Record 20 of Set 2 | san martin
# Processing Record 21 of Set 2 | half moon bay
# Processing Record 22 of Set 2 | choix
# Processing Record 23 of Set 2 | vallenar
# Processing Record 24 of Set 2 | sinnamary
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | xai-xai
# Processing Record 27 of Set 2 | porto novo
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 2 | zhigalovo
# Processing Record 30 of Set 2 | ayan
# Processing Record 31 of Set 2 | mayumba
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | iqaluit
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | tasiilaq
# Processing Record 36 of Set 2 | kavaratti
# Processing Record 37 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 2 | touros
# Processing Record 39 of Set 2 | schonebeck
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | juneau
# Processing Record 42 of Set 2 | nanortalik
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | marzuq
# Processing Record 45 of Set 2 | tyrma
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | codrington
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | provideniya
# Processing Record 2 of Set 3 | laguna
# Processing Record 3 of Set 3 | mount isa
# Processing Record 4 of Set 3 | les cayes
# Processing Record 5 of Set 3 | mandera
# Processing Record 6 of Set 3 | solnechnyy
# Processing Record 7 of Set 3 | dingli
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 3 | constitucion
# Processing Record 12 of Set 3 | paamiut
# Processing Record 13 of Set 3 | pokhara
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 16 of Set 3 | bathsheba
# Processing Record 17 of Set 3 | biltine
# Processing Record 18 of Set 3 | baicheng
# Processing Record 19 of Set 3 | port hardy
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | mende
# Processing Record 22 of Set 3 | hobyo
# Processing Record 23 of Set 3 | copiapo
# Processing Record 24 of Set 3 | santa isabel do rio negro
# Processing Record 25 of Set 3 | truro
# Processing Record 26 of Set 3 | te anau
# Processing Record 27 of Set 3 | maraa
# Processing Record 28 of Set 3 | coihaique
# Processing Record 29 of Set 3 | margate
# Processing Record 30 of Set 3 | vorotynets
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | barrow
# Processing Record 33 of Set 3 | tabou
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 3 | szczecin
# Processing Record 37 of Set 3 | nikolskoye
# Processing Record 38 of Set 3 | karratha
# Processing Record 39 of Set 3 | ardistan
# City not found. Skipping...
# Processing Record 40 of Set 3 | kashi
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | jieshi
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | bac lieu
# Processing Record 45 of Set 3 | kundla
# Processing Record 46 of Set 3 | mana
# Processing Record 47 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | praia
# Processing Record 50 of Set 3 | tetiz
# Processing Record 1 of Set 4 | bilma
# Processing Record 2 of Set 4 | buala
# Processing Record 3 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | aguimes
# Processing Record 6 of Set 4 | palomares
# Processing Record 7 of Set 4 | airai
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | butte
# Processing Record 10 of Set 4 | mehamn
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | warri
# Processing Record 13 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 14 of Set 4 | olinda
# Processing Record 15 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 4 | geraldton
# Processing Record 17 of Set 4 | cherskiy
# Processing Record 18 of Set 4 | ponot
# Processing Record 19 of Set 4 | umm lajj
# Processing Record 20 of Set 4 | eureka
# Processing Record 21 of Set 4 | kyshtovka
# Processing Record 22 of Set 4 | tres passos
# Processing Record 23 of Set 4 | jamestown
# Processing Record 24 of Set 4 | bethel
# Processing Record 25 of Set 4 | tuatapere
# Processing Record 26 of Set 4 | new norfolk
# Processing Record 27 of Set 4 | rafaela
# Processing Record 28 of Set 4 | rockhampton
# Processing Record 29 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 4 | beringovskiy
# Processing Record 31 of Set 4 | sosnovo-ozerskoye
# Processing Record 32 of Set 4 | los llanos de aridane
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | biak
# Processing Record 35 of Set 4 | hambantota
# Processing Record 36 of Set 4 | noyabrsk
# Processing Record 37 of Set 4 | vila
# Processing Record 38 of Set 4 | othonoi
# City not found. Skipping...
# Processing Record 39 of Set 4 | sakakah
# Processing Record 40 of Set 4 | kudahuvadhoo
# Processing Record 41 of Set 4 | fortuna
# Processing Record 42 of Set 4 | guerrero negro
# Processing Record 43 of Set 4 | marawi
# Processing Record 44 of Set 4 | mangrol
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | nelson bay
# Processing Record 47 of Set 4 | la rochelle
# Processing Record 48 of Set 4 | poum
# Processing Record 49 of Set 4 | lexington
# Processing Record 50 of Set 4 | abnub
# Processing Record 1 of Set 5 | kindia
# Processing Record 2 of Set 5 | taltal
# Processing Record 3 of Set 5 | gari
# Processing Record 4 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 5 | pisco
# Processing Record 6 of Set 5 | esperance
# Processing Record 7 of Set 5 | jinka
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | high level
# Processing Record 10 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 11 of Set 5 | oistins
# Processing Record 12 of Set 5 | tacuarembo
# Processing Record 13 of Set 5 | guangyuan
# Processing Record 14 of Set 5 | avera
# Processing Record 15 of Set 5 | oussouye
# Processing Record 16 of Set 5 | kahului
# Processing Record 17 of Set 5 | milkovo
# Processing Record 18 of Set 5 | port hedland
# Processing Record 19 of Set 5 | mpika
# Processing Record 20 of Set 5 | yulara
# Processing Record 21 of Set 5 | bagepalli
# Processing Record 22 of Set 5 | mahebourg
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | alekseyevka
# Processing Record 25 of Set 5 | alice springs
# Processing Record 26 of Set 5 | ostrovnoy
# Processing Record 27 of Set 5 | aktas
# Processing Record 28 of Set 5 | araouane
# Processing Record 29 of Set 5 | sibolga
# Processing Record 30 of Set 5 | chartres
# Processing Record 31 of Set 5 | searcy
# Processing Record 32 of Set 5 | shelburne
# Processing Record 33 of Set 5 | aklavik
# Processing Record 34 of Set 5 | dolores
# Processing Record 35 of Set 5 | alta floresta
# Processing Record 36 of Set 5 | padang
# Processing Record 37 of Set 5 | vestmannaeyjar
# Processing Record 38 of Set 5 | hima
# Processing Record 39 of Set 5 | adrar
# Processing Record 40 of Set 5 | faya
# Processing Record 41 of Set 5 | palm coast
# Processing Record 42 of Set 5 | aksarka
# Processing Record 43 of Set 5 | saint-philippe
# Processing Record 44 of Set 5 | bandarbeyla
# Processing Record 45 of Set 5 | gravdal
# Processing Record 46 of Set 5 | waingapu
# Processing Record 47 of Set 5 | tura
# Processing Record 48 of Set 5 | miraflores
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | vanimo
# Processing Record 1 of Set 6 | budogoshch
# Processing Record 2 of Set 6 | puro
# Processing Record 3 of Set 6 | parana
# Processing Record 4 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 6 | richards bay
# Processing Record 7 of Set 6 | yellowknife
# Processing Record 8 of Set 6 | batsfjord
# Processing Record 9 of Set 6 | matagami
# Processing Record 10 of Set 6 | samarai
# Processing Record 11 of Set 6 | ribeira brava
# Processing Record 12 of Set 6 | katsuura
# Processing Record 13 of Set 6 | houyet
# Processing Record 14 of Set 6 | luderitz
# Processing Record 15 of Set 6 | katherine
# Processing Record 16 of Set 6 | mnogovershinnyy
# Processing Record 17 of Set 6 | dingle
# Processing Record 18 of Set 6 | lagoa
# Processing Record 19 of Set 6 | raga
# Processing Record 20 of Set 6 | berlevag
# Processing Record 21 of Set 6 | erenhot
# Processing Record 22 of Set 6 | sonoita
# Processing Record 23 of Set 6 | torbay
# Processing Record 24 of Set 6 | rumford
# Processing Record 25 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 26 of Set 6 | sam roi yot
# Processing Record 27 of Set 6 | narsaq
# Processing Record 28 of Set 6 | kitimat
# Processing Record 29 of Set 6 | matara
# Processing Record 30 of Set 6 | arraial do cabo
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 | las palmas
# Processing Record 33 of Set 6 | koslan
# Processing Record 34 of Set 6 | rio grande
# Processing Record 35 of Set 6 | chokwe
# Processing Record 36 of Set 6 | marovoay
# Processing Record 37 of Set 6 | roebourne
# Processing Record 38 of Set 6 | narasannapeta
# Processing Record 39 of Set 6 | ust-maya
# Processing Record 40 of Set 6 | batagay
# Processing Record 41 of Set 6 | itaituba
# Processing Record 42 of Set 6 | sola
# Processing Record 43 of Set 6 | vostochnyy
# Processing Record 44 of Set 6 | ilulissat
# Processing Record 45 of Set 6 | havre-saint-pierre
# Processing Record 46 of Set 6 | yaring
# Processing Record 47 of Set 6 | husavik
# Processing Record 48 of Set 6 | sao filipe
# Processing Record 49 of Set 6 | urvan
# Processing Record 50 of Set 6 | anadyr
# Processing Record 1 of Set 7 | kamenka
# Processing Record 2 of Set 7 | port macquarie
# Processing Record 3 of Set 7 | hamilton
# Processing Record 4 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 7 | pouembout
# Processing Record 6 of Set 7 | marienburg
# Processing Record 7 of Set 7 | jaca
# Processing Record 8 of Set 7 | mayo
# Processing Record 9 of Set 7 | honningsvag
# Processing Record 10 of Set 7 | atbasar
# Processing Record 11 of Set 7 | witu
# Processing Record 12 of Set 7 | la ronge
# Processing Record 13 of Set 7 | belyy yar
# Processing Record 14 of Set 7 | dehui
# Processing Record 15 of Set 7 | tuy hoa
# Processing Record 16 of Set 7 | voskresenskoye
# Processing Record 17 of Set 7 | lebu
# Processing Record 18 of Set 7 | khani
# Processing Record 19 of Set 7 | dudinka
# Processing Record 20 of Set 7 | wagga wagga
# Processing Record 21 of Set 7 | umm kaddadah
# Processing Record 22 of Set 7 | chokurdakh
# Processing Record 23 of Set 7 | coari
# Processing Record 24 of Set 7 | santa lucia
# Processing Record 25 of Set 7 | ishigaki
# Processing Record 26 of Set 7 | clyde river
# Processing Record 27 of Set 7 | kishorganj
# Processing Record 28 of Set 7 | baiyin
# Processing Record 29 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 7 | mackay
# Processing Record 31 of Set 7 | behshahr
# Processing Record 32 of Set 7 | slantsy
# Processing Record 33 of Set 7 | san quintin
# Processing Record 34 of Set 7 | harper
# Processing Record 35 of Set 7 | camargo
# Processing Record 36 of Set 7 | alexandria
# Processing Record 37 of Set 7 | marystown
# Processing Record 38 of Set 7 | solano
# Processing Record 39 of Set 7 | kharan
# Processing Record 40 of Set 7 | shingu
# Processing Record 41 of Set 7 | najran
# Processing Record 42 of Set 7 | sambava
# Processing Record 43 of Set 7 | issaquah
# Processing Record 44 of Set 7 | duvan
# Processing Record 45 of Set 7 | tessalit
# Processing Record 46 of Set 7 | karnobat
# Processing Record 47 of Set 7 | martapura
# Processing Record 48 of Set 7 | kalmunai
# Processing Record 49 of Set 7 | henties bay
# Processing Record 50 of Set 7 | karasjok
# Processing Record 1 of Set 8 | gobabis
# Processing Record 2 of Set 8 | hofn
# Processing Record 3 of Set 8 | rodniki
# Processing Record 4 of Set 8 | hasaki
# Processing Record 5 of Set 8 | soyo
# Processing Record 6 of Set 8 | kruisfontein
# Processing Record 7 of Set 8 | amapa
# Processing Record 8 of Set 8 | qasigiannguit
# Processing Record 9 of Set 8 | bam
# Processing Record 10 of Set 8 | cockburn town
# Processing Record 11 of Set 8 | cape canaveral
# Processing Record 12 of Set 8 | show low
# Processing Record 13 of Set 8 | khandyga
# Processing Record 14 of Set 8 | hecun
# Processing Record 15 of Set 8 | san pedro
# Processing Record 16 of Set 8 | zheleznogorsk-ilimskiy
# Processing Record 17 of Set 8 | shancheng
# Processing Record 18 of Set 8 | upernavik
# Processing Record 19 of Set 8 | verkhnyaya inta
# Processing Record 20 of Set 8 | lubango
# Processing Record 21 of Set 8 | santa marta
# Processing Record 22 of Set 8 | wilmington
# Processing Record 23 of Set 8 | kencong
# Processing Record 24 of Set 8 | calafell
# Processing Record 25 of Set 8 | nyurba
# Processing Record 26 of Set 8 | tromso
# Processing Record 27 of Set 8 | general roca
# Processing Record 28 of Set 8 | amqui
# Processing Record 29 of Set 8 | atar
# Processing Record 30 of Set 8 | leshukonskoye
# Processing Record 31 of Set 8 | cururupu
# Processing Record 32 of Set 8 | dawlatabad
# Processing Record 33 of Set 8 | halifax
# Processing Record 34 of Set 8 | kuytun
# Processing Record 35 of Set 8 | talnakh
# Processing Record 36 of Set 8 | necochea
# Processing Record 37 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 8 | zhanaozen
# Processing Record 39 of Set 8 | vysokogornyy
# Processing Record 40 of Set 8 | sayyan
# Processing Record 41 of Set 8 | mounana
# Processing Record 42 of Set 8 | verkhnevilyuysk
# Processing Record 43 of Set 8 | severodvinsk
# Processing Record 44 of Set 8 | fort nelson
# Processing Record 45 of Set 8 | oberhausen-rheinhausen
# Processing Record 46 of Set 8 | freeport
# Processing Record 47 of Set 8 | lulea
# Processing Record 48 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 8 | kayes
# Processing Record 50 of Set 8 | rawson
# Processing Record 1 of Set 9 | sandy bay
# Processing Record 2 of Set 9 | minab
# Processing Record 3 of Set 9 | kijang
# Processing Record 4 of Set 9 | rocha
# Processing Record 5 of Set 9 | labrea
# Processing Record 6 of Set 9 | lynn haven
# Processing Record 7 of Set 9 | port-gentil
# Processing Record 8 of Set 9 | ust-koksa
# Processing Record 9 of Set 9 | saint-michel-des-saints
# Processing Record 10 of Set 9 | gijon
# Processing Record 11 of Set 9 | kuloy
# Processing Record 12 of Set 9 | qaqortoq
# Processing Record 13 of Set 9 | chapais
# Processing Record 14 of Set 9 | rio gallegos
# Processing Record 15 of Set 9 | mahibadhoo
# Processing Record 16 of Set 9 | namatanai
# Processing Record 17 of Set 9 | kemijarvi
# Processing Record 18 of Set 9 | dali
# Processing Record 19 of Set 9 | ust-nera
# Processing Record 20 of Set 9 | yermakovskoye
# Processing Record 21 of Set 9 | luanda
# Processing Record 22 of Set 9 | victoria
# Processing Record 23 of Set 9 | canela
# Processing Record 24 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 9 | port keats
# Processing Record 26 of Set 9 | dakar
# Processing Record 27 of Set 9 | zhigansk
# Processing Record 28 of Set 9 | granville
# Processing Record 29 of Set 9 | vila velha
# Processing Record 30 of Set 9 | torbat-e jam
# Processing Record 31 of Set 9 | akcaabat
# Processing Record 32 of Set 9 | sorong
# Processing Record 33 of Set 9 | kibakwe
# Processing Record 34 of Set 9 | khabary
# Processing Record 35 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 36 of Set 9 | bratskoye
# Processing Record 37 of Set 9 | sechura
# Processing Record 38 of Set 9 | iisalmi
# Processing Record 39 of Set 9 | sistranda
# Processing Record 40 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 9 | jiayuguan
# Processing Record 43 of Set 9 | auki
# Processing Record 44 of Set 9 | labuhan
# Processing Record 45 of Set 9 | mount gambier
# Processing Record 46 of Set 9 | tazovskiy
# Processing Record 47 of Set 9 | trincomalee
# Processing Record 48 of Set 9 | shimoda
# Processing Record 49 of Set 9 | sisimiut
# Processing Record 50 of Set 9 | north bend
# Processing Record 1 of Set 10 | saint george
# Processing Record 2 of Set 10 | cortez
# Processing Record 3 of Set 10 | baculin
# Processing Record 4 of Set 10 | carutapera
# Processing Record 5 of Set 10 | krasnoselkup
# Processing Record 6 of Set 10 | ballina
# Processing Record 7 of Set 10 | hammerfest
# Processing Record 8 of Set 10 | fengcheng
# Processing Record 9 of Set 10 | hukuntsi
# Processing Record 10 of Set 10 | parabel
# Processing Record 11 of Set 10 | awjilah
# Processing Record 12 of Set 10 | hovd
# Processing Record 13 of Set 10 | inhambane
# Processing Record 14 of Set 10 | springbok
# Processing Record 15 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 10 | imbituba
# Processing Record 17 of Set 10 | fomboni
# Processing Record 18 of Set 10 | adolfo lopez mateos
# Processing Record 19 of Set 10 | bowen
# Processing Record 20 of Set 10 | tomatlan
# Processing Record 21 of Set 10 | lorengau
# Processing Record 22 of Set 10 | kodinsk
# Processing Record 23 of Set 10 | kisanga
# Processing Record 24 of Set 10 | vostok
# Processing Record 25 of Set 10 | teya
# Processing Record 26 of Set 10 | alice town
# Processing Record 27 of Set 10 | klaksvik
# Processing Record 28 of Set 10 | general delgado
# Processing Record 29 of Set 10 | hopelchen
# Processing Record 30 of Set 10 | yerbogachen
# Processing Record 31 of Set 10 | caravelas
# Processing Record 32 of Set 10 | borujerd
# Processing Record 33 of Set 10 | daru
# Processing Record 34 of Set 10 | udachnyy
# Processing Record 35 of Set 10 | bereznik
# Processing Record 36 of Set 10 | beboto
# Processing Record 37 of Set 10 | duiwelskloof
# Processing Record 38 of Set 10 | isangel
# Processing Record 39 of Set 10 | comodoro rivadavia
# Processing Record 40 of Set 10 | pitea
# Processing Record 41 of Set 10 | aykhal
# Processing Record 42 of Set 10 | barda
# Processing Record 43 of Set 10 | oktyabrskiy
# Processing Record 44 of Set 10 | sur
# Processing Record 45 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 10 | qandala
# Processing Record 47 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 48 of Set 10 | todos santos
# Processing Record 49 of Set 10 | lethem
# Processing Record 50 of Set 10 | sittingbourne
# Processing Record 1 of Set 11 | lastoursville
# Processing Record 2 of Set 11 | mawlaik
# Processing Record 3 of Set 11 | barranca
# Processing Record 4 of Set 11 | deputatskiy
# Processing Record 5 of Set 11 | ligayan
# Processing Record 6 of Set 11 | sunrise manor
# Processing Record 7 of Set 11 | mujiayingzi
# Processing Record 8 of Set 11 | ossora
# Processing Record 9 of Set 11 | manokwari
# Processing Record 10 of Set 11 | xucheng
# Processing Record 11 of Set 11 | port hawkesbury
# Processing Record 12 of Set 11 | caruray
# Processing Record 13 of Set 11 | broome
# Processing Record 14 of Set 11 | vao
# Processing Record 15 of Set 11 | kanigoro
# Processing Record 16 of Set 11 | pomabamba
# Processing Record 17 of Set 11 | kununurra
# Processing Record 18 of Set 11 | cabedelo
# Processing Record 19 of Set 11 | thunder bay
# Processing Record 20 of Set 11 | zaria
# Processing Record 21 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 22 of Set 11 | lavrentiya
# Processing Record 23 of Set 11 | rio rancho
# Processing Record 24 of Set 11 | mahina
# Processing Record 25 of Set 11 | villazon
# Processing Record 26 of Set 11 | mitsamiouli
# Processing Record 27 of Set 11 | garissa
# Processing Record 28 of Set 11 | castelldefels
# Processing Record 29 of Set 11 | pa sang
# Processing Record 30 of Set 11 | iraquara
# Processing Record 31 of Set 11 | loreto
# Processing Record 32 of Set 11 | pechea
# Processing Record 33 of Set 11 | sysert
# Processing Record 34 of Set 11 | galesong
# Processing Record 35 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 36 of Set 11 | ahipara
# Processing Record 37 of Set 11 | pochutla
# Processing Record 38 of Set 11 | puerto narino
# Processing Record 39 of Set 11 | dole
# Processing Record 40 of Set 11 | yumen
# Processing Record 41 of Set 11 | hami
# Processing Record 42 of Set 11 | vrangel
# Processing Record 43 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 11 | san patricio
# Processing Record 45 of Set 11 | dwarka
# Processing Record 46 of Set 11 | sobolevo
# Processing Record 47 of Set 11 | skelleftea
# Processing Record 48 of Set 11 | zhezkazgan
# Processing Record 49 of Set 11 | purpe
# Processing Record 50 of Set 11 | svetlogorsk
# Processing Record 1 of Set 12 | hanyang
# Processing Record 2 of Set 12 | nhulunbuy
# Processing Record 3 of Set 12 | jinchang
# Processing Record 4 of Set 12 | angoche
# Processing Record 5 of Set 12 | bonavista
# Processing Record 6 of Set 12 | huarmey
# Processing Record 7 of Set 12 | boralday
# Processing Record 8 of Set 12 | malakal
# Processing Record 9 of Set 12 | faanui
# Processing Record 10 of Set 12 | lampang
# Processing Record 11 of Set 12 | weligama
# Processing Record 12 of Set 12 | slave lake
# Processing Record 13 of Set 12 | iranduba
# Processing Record 14 of Set 12 | kokkola
# Processing Record 15 of Set 12 | jacksonville beach
# Processing Record 16 of Set 12 | interlaken
# Processing Record 17 of Set 12 | chaozhou
# Processing Record 18 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 12 | aswan
# Processing Record 20 of Set 12 | esil
# Processing Record 21 of Set 12 | kemi
# Processing Record 22 of Set 12 | college
# Processing Record 23 of Set 12 | homer
# Processing Record 24 of Set 12 | karakol
# Processing Record 25 of Set 12 | varhaug
# Processing Record 26 of Set 12 | bengkalis
# City not found. Skipping...
# Processing Record 27 of Set 12 | hearst
# Processing Record 28 of Set 12 | mombetsu
# Processing Record 29 of Set 12 | sitka
# Processing Record 30 of Set 12 | gwanda
# Processing Record 31 of Set 12 | pangkalanbuun
# Processing Record 32 of Set 12 | bereda
# Processing Record 33 of Set 12 | urengoy
# Processing Record 34 of Set 12 | vila franca do campo
# Processing Record 35 of Set 12 | ciudad real
# Processing Record 36 of Set 12 | haines junction
# Processing Record 37 of Set 12 | coahuayana
# Processing Record 38 of Set 12 | magalia
# Processing Record 39 of Set 12 | whitehorse
# Processing Record 40 of Set 12 | montbrison
# Processing Record 41 of Set 12 | basqal
# Processing Record 42 of Set 12 | quchan
# Processing Record 43 of Set 12 | bima
# Processing Record 44 of Set 12 | praia da vitoria
# Processing Record 45 of Set 12 | atlantis
# Processing Record 46 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 12 | haapsalu
# Processing Record 48 of Set 12 | sorland
# Processing Record 49 of Set 12 | saint-augustin
# Processing Record 50 of Set 12 | muros
# Processing Record 1 of Set 13 | brignais
# Processing Record 2 of Set 13 | mogadishu
# Processing Record 3 of Set 13 | abasolo
# Processing Record 4 of Set 13 | qianan
# Processing Record 5 of Set 13 | gat
# Processing Record 6 of Set 13 | cap malheureux
# Processing Record 7 of Set 13 | ranong
# Processing Record 8 of Set 13 | byron bay
# Processing Record 9 of Set 13 | kapoeta
# Processing Record 10 of Set 13 | vitim
# Processing Record 11 of Set 13 | denpasar
# Processing Record 12 of Set 13 | northam
# Processing Record 13 of Set 13 | altea
# Processing Record 14 of Set 13 | mecca
# Processing Record 15 of Set 13 | funadhoo
# Processing Record 16 of Set 13 | bukene
# Processing Record 17 of Set 13 | nago
# Processing Record 18 of Set 13 | palembang
# Processing Record 19 of Set 13 | bitung
# Processing Record 20 of Set 13 | chake chake
# Processing Record 21 of Set 13 | maarianhamina
# Processing Record 22 of Set 13 | merauke
# Processing Record 23 of Set 13 | khasan
# Processing Record 24 of Set 13 | san policarpo
# Processing Record 25 of Set 13 | tuysarkan
# City not found. Skipping...
# Processing Record 26 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 27 of Set 13 | sicamous
# Processing Record 28 of Set 13 | abashiri
# Processing Record 29 of Set 13 | toamasina
# Processing Record 30 of Set 13 | kalmar
# Processing Record 31 of Set 13 | banting
# Processing Record 32 of Set 13 | kaeo
# Processing Record 33 of Set 13 | dubbo
# Processing Record 34 of Set 13 | navrongo
# Processing Record 35 of Set 13 | obluche
# City not found. Skipping...
# Processing Record 36 of Set 13 | east bethel
# Processing Record 37 of Set 13 | dezhou
# Processing Record 38 of Set 13 | le pradet
# Processing Record 39 of Set 13 | huicungo
# Processing Record 40 of Set 13 | natchitoches
# Processing Record 41 of Set 13 | wilkie
# Processing Record 42 of Set 13 | altagracia de orituco
# Processing Record 43 of Set 13 | gharghoda
# Processing Record 44 of Set 13 | hoyanger
# Processing Record 45 of Set 13 | rudnya
# Processing Record 46 of Set 13 | lahan
# Processing Record 47 of Set 13 | tautira
# Processing Record 48 of Set 13 | ternate
# Processing Record 49 of Set 13 | brae
# Processing Record 50 of Set 13 | sikasso
# Processing Record 1 of Set 14 | nola
# Processing Record 2 of Set 14 | khakhea
# Processing Record 3 of Set 14 | hualmay
# Processing Record 4 of Set 14 | isiro
# Processing Record 5 of Set 14 | egvekinot
# Processing Record 6 of Set 14 | srednekolymsk
# Processing Record 7 of Set 14 | blonduos
# City not found. Skipping...
# Processing Record 8 of Set 14 | abu kamal
# Processing Record 9 of Set 14 | yuncheng
# Processing Record 10 of Set 14 | snasa
# Processing Record 11 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 14 | nizhniy kuranakh
# Processing Record 13 of Set 14 | staraya toropa
# Processing Record 14 of Set 14 | umea
# Processing Record 15 of Set 14 | sioux lookout
# Processing Record 16 of Set 14 | belen
# Processing Record 17 of Set 14 | honiara
# Processing Record 18 of Set 14 | thinadhoo
# Processing Record 19 of Set 14 | moses lake
# Processing Record 20 of Set 14 | port lincoln
# Processing Record 21 of Set 14 | manakara
# Processing Record 22 of Set 14 | batagay-alyta
# Processing Record 23 of Set 14 | lusaka
# Processing Record 24 of Set 14 | erzin
# Processing Record 25 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 26 of Set 14 | shintomi
# Processing Record 27 of Set 14 | la libertad
# Processing Record 28 of Set 14 | sarahan
# Processing Record 29 of Set 14 | lander
# Processing Record 30 of Set 14 | agadir
# Processing Record 31 of Set 14 | muravlenko
# Processing Record 32 of Set 14 | buraydah
# Processing Record 33 of Set 14 | saint-pierre
# Processing Record 34 of Set 14 | muzhi
# Processing Record 35 of Set 14 | banda aceh
# Processing Record 36 of Set 14 | itarema
# Processing Record 37 of Set 14 | pascagoula
# Processing Record 38 of Set 14 | jasper
# Processing Record 39 of Set 14 | bayir
# Processing Record 40 of Set 14 | bajah
# Processing Record 41 of Set 14 | gamba
# Processing Record 42 of Set 14 | starozhilovo
# Processing Record 43 of Set 14 | krasnyy yar
# Processing Record 44 of Set 14 | nyahururu
# Processing Record 45 of Set 14 | namuac
# Processing Record 46 of Set 14 | lumeje
# Processing Record 47 of Set 14 | marsa matruh
# Processing Record 48 of Set 14 | seoul
# Processing Record 49 of Set 14 | portpatrick
# City not found. Skipping...
# Processing Record 50 of Set 14 | sungaipenuh
# Processing Record 1 of Set 15 | bara
# Processing Record 2 of Set 15 | revda
# Processing Record 3 of Set 15 | rovaniemi
# Processing Record 4 of Set 15 | yian
# City not found. Skipping...
# Processing Record 5 of Set 15 | burlington
# Processing Record 6 of Set 15 | torres
# Processing Record 7 of Set 15 | colac
# Processing Record 8 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 9 of Set 15 | ventspils
# Processing Record 10 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 11 of Set 15 | kasongo-lunda
# Processing Record 12 of Set 15 | mantua
# Processing Record 13 of Set 15 | san diego de los banos
# Processing Record 14 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 15 | mareeba
# Processing Record 16 of Set 15 | pandan
# Processing Record 17 of Set 15 | komsomolskiy
# Processing Record 18 of Set 15 | bassano
# Processing Record 19 of Set 15 | eydhafushi
# Processing Record 20 of Set 15 | vicam
# Processing Record 21 of Set 15 | meulaboh
# Processing Record 22 of Set 15 | ukiah
# Processing Record 23 of Set 15 | nome
# Processing Record 24 of Set 15 | poindimie
# Processing Record 25 of Set 15 | fernley
# Processing Record 26 of Set 15 | nobeoka
# Processing Record 27 of Set 15 | sanandaj
# Processing Record 28 of Set 15 | vanavara
# Processing Record 29 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 30 of Set 15 | ginda
# Processing Record 31 of Set 15 | palmer
# Processing Record 32 of Set 15 | sept-iles
# Processing Record 33 of Set 15 | taloda
# Processing Record 34 of Set 15 | shakhtinsk
# Processing Record 35 of Set 15 | plettenberg bay
# Processing Record 36 of Set 15 | bairiki
# Processing Record 37 of Set 15 | porosozero
# Processing Record 38 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 40 of Set 15 | bagrami
# Processing Record 41 of Set 15 | ndele
# Processing Record 42 of Set 15 | pithiviers
# Processing Record 43 of Set 15 | maniitsoq
# Processing Record 44 of Set 15 | teguise
# Processing Record 45 of Set 15 | banamba
# Processing Record 46 of Set 15 | roblin
# Processing Record 47 of Set 15 | mezen
# Processing Record 48 of Set 15 | nichinan
# Processing Record 49 of Set 15 | miandrivazo
# Processing Record 50 of Set 15 | quatre cocos
# Processing Record 1 of Set 16 | catuday
# Processing Record 2 of Set 16 | jennings
# Processing Record 3 of Set 16 | grand gaube
# Processing Record 4 of Set 16 | luyang
# Processing Record 5 of Set 16 | svetlaya
# Processing Record 6 of Set 16 | petatlan
# Processing Record 7 of Set 16 | acapulco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Rikitea -23.1203 -134.9692     74.39        75           3
# 1              Chuy -33.6971  -53.4616     58.42        91         100
# 2     Mar Del Plata -38.0023  -57.5575     52.27        72           3
# 3       Antofagasta -23.6500  -70.4000     56.48        63          35
# 4             Kapaa  22.0752 -159.3190     73.38        79          11
# 5     San Cristobal   7.7669  -72.2250     77.05        57          98
# 6            Atuona  -9.8000 -139.0333     77.70        71           8
# 7   Bambous Virieux -20.3428   57.7575     70.05        68          75
# 8  Staraya Poltavka  50.4772   46.4814     95.13        12         100
# 9            Avarua -21.2078 -159.7750     66.25       100          75
#
#    Wind Speed Country Current Description
# 0       15.12      PF           clear sky
# 1        3.36      UY     overcast clouds
# 2        7.31      AR           clear sky
# 3        7.74      CL    scattered clouds
# 4       12.08      US       moderate rain
# 5        4.47      VE     overcast clouds
# 6       19.24      PF           clear sky
# 7       12.66      MU       broken clouds
# 8        9.06      RU     overcast clouds
# 9        1.14      CK       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea      PF -23.1203 -134.9692     74.39        75           3
# 1             Chuy      UY -33.6971  -53.4616     58.42        91         100
# 2    Mar Del Plata      AR -38.0023  -57.5575     52.27        72           3
# 3      Antofagasta      CL -23.6500  -70.4000     56.48        63          35
# 4            Kapaa      US  22.0752 -159.3190     73.38        79          11
# ..             ...     ...      ...       ...       ...       ...         ...
# 698    Grand Gaube      MU -20.0064   57.6608     68.38        64          60
# 699         Luyang      CN  27.6239  110.0989     70.29        99          97
# 700       Svetlaya      RU  46.5389  138.3297     56.23        87          48
# 701       Petatlan      MX  17.5167 -101.2667     80.40        82          14
# 702       Acapulco      MX  16.8634  -99.8901     82.22        78          40
#
#      Wind Speed Current Description
# 0         15.12           clear sky
# 1          3.36     overcast clouds
# 2          7.31           clear sky
# 3          7.74    scattered clouds
# 4         12.08       moderate rain
# ..          ...                 ...
# 698        5.99       broken clouds
# 699        2.19     overcast clouds
# 700        3.22    scattered clouds
# 701        2.82          few clouds
# 702        3.44    scattered clouds
#
# [703 rows x 9 columns]

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 73.47,
#   'feels_like': 73.11,
#   'temp_min': 69.48,
#   'temp_max': 77.23,
#   'pressure': 1023,
#   'humidity': 55},
#  'visibility': 10000,
#  'wind': {'speed': 7, 'deg': 60, 'gust': 15.99},
#  'clouds': {'all': 40},
#  'dt': 1629036780,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1629021106,
#   'sunset': 1629071150},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
